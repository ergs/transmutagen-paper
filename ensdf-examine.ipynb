# %%
from pyne import ensdf
# Out:
# /home/scopatz/miniconda/lib/python3.6/importlib/_bootstrap.py:219: QAWarning: pyne.rxname is not yet QA compliant.
#   return f(*args, **kwds)
# /home/scopatz/miniconda/lib/python3.6/importlib/_bootstrap.py:219: QAWarning: pyne.data is not yet QA compliant.
#   return f(*args, **kwds)
# /home/scopatz/.local/lib/python3.6/site-packages/pyne/ensdf.py:17: QAWarning: pyne.ensdf is not yet QA compliant.
#   warn(__name__ + " is not yet QA compliant.", QAWarning)

# %%
filename = '/home/scopatz/build_nuc_data/ENSDF/ensdf.153'
n = 71
data = ensdf.levels(filename)
[row for row in data if row[0]//10000000 == n]
# Out:
# [(711530000, 1089, 0.9, 0.0, 70.0, 0, ' '),
#  (711530000, 3182278881, 0.9, 0.0, 30.0, 0, ' '),
#  (711530000, 0, 0.9, 0.0, 0.0, 0, ' '),
#  (711530001, 0, None, 80.0, 0.0, 0, ' '),
#  (711530002, 0, None, 1432.1, 0.0, 0, ' '),
#  (711530003, 0, None, 1606.2, 0.0, 0, ' '),
#  (711530004, 0, None, 1822.7, 0.0, 0, ' '),
#  (711530005, 0, None, 2147.0, 0.0, 0, ' '),
#  (711530006, 0, None, 2211.6, 0.0, 0, ' '),
#  (711530007, 0, None, 2481.6, 0.0, 0, ' '),
#  (711530008, 0, 1e-07, 2502.5, 0.0, 0, ' '),
#  (711530009, 0, 1.4999999999999999e-05, 2632.9, 0.0, 0, ' ')]

# %%
filename = '/home/scopatz/build_nuc_data/ENSDF/ensdf.154'
data = ensdf.levels(filename)
data
# Out:
# [(571540000, 4130566254, 0.161, 0.0, 100.0, 0, ' '),
#  (571540000, 0, 0.161, 0.0, 0.0, 0, ' '),
#  (581540000, 4130566254, 1.0000000000000001e-07, 0.0, 100.0, 0, ' '),
#  (581540000, 0, 1.0000000000000001e-07, 0.0, 0.0, 0, ' '),
#  (591540000, 4130566254, 2.3, 0.0, 100.0, 0, ' '),
#  (591540000, 0, 2.3, 0.0, 0.0, 0, ' '),
#  (601540000, 4130566254, 25.9, 0.0, 100.0, 0, ' '),
#  (601540000, 0, 25.9, 0.0, 0.0, 0, ' '),
#  (601540001, 0, 7.700000000000001e-09, 70.8, 0.0, 0, ' '),
#  (601540002, 0, None, 233.2, 0.0, 0, ' '),
#  (601540003, 0, 1.3e-06, 233.2, 0.0, 1, 'X'),
#  (601540004, 0, None, 481.9, 0.0, 0, ' '),
#  (601540005, 0, None, 810.1, 0.0, 0, ' '),
#  (601540006, 0, None, 961.6, 0.0, 0, ' '),
#  (601540007, 0, None, 1003.1, 0.0, 0, ' '),
#  (601540008, 0, None, 1027.6, 0.0, 0, ' '),
#  (601540009, 0, None, 1128.4, 0.0, 0, ' '),
#  (601540010, 0, None, 1210.8, 0.0, 0, ' '),
#  (601540011, 0, None, 1325.8, 0.0, 0, ' '),
#  (601540012, 0, 1e-06, 1349.0, 0.0, 0, ' '),
# ...
