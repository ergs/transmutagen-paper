# %%
from pyne.gui.decaychain import graph
# Out:
# /home/scopatz/miniconda3/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.data is not yet QA compliant.
#   return f(*args, **kwds)
# /home/scopatz/miniconda3/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.rxname is not yet QA compliant.
#   return f(*args, **kwds)

# %%
graph('Cm250')

# %%
g = graph('Cm250')

# %%
g.render('cm250.svg')
# Out:
# 'cm250.svg.pdf'
